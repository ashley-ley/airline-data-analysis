# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# Store filepath in a variable
us_weather_path = Path("united_states_weather.csv")

# %%
# Read our data file with the Pandas library
# Not every CSV requires an encoding, but be aware this can come up
us_weather_df = pd.read_csv(us_weather_path, encoding="ISO-8859-1")

# %%
# Show the first five rows.
us_weather_df.head()
# Out:
#   EventId  Type Severity       StartTime(UTC)         EndTime(UTC)  \
# 0     W-1  Snow    Light  2016-01-06 23:14:00  2016-01-07 00:34:00
# 1     W-2  Snow    Light  2016-01-07 04:14:00  2016-01-07 04:54:00
# 2     W-3  Snow    Light  2016-01-07 05:54:00  2016-01-07 15:34:00
# 3     W-4  Snow    Light  2016-01-08 05:34:00  2016-01-08 05:54:00
# 4     W-5  Snow    Light  2016-01-08 13:54:00  2016-01-08 15:54:00
#
#    Precipitation(in)     TimeZone AirportCode  LocationLat  LocationLng  \
# 0               0.00  US/Mountain        K04V      38.0972    -106.1689
# 1               0.00  US/Mountain        K04V      38.0972    -106.1689
# 2               0.03  US/Mountain        K04V      38.0972    -106.1689
# 3               0.00  US/Mountain        K04V      38.0972    -106.1689
# 4               0.00  US/Mountain        K04V      38.0972    -106.1689
#
#        City    County State  ZipCode
# 0  Saguache  Saguache    CO  81149.0
# 1  Saguache  Saguache    CO  81149.0
# ...

# %%
us_weather_df.count()
# Out:
# EventId              8627181
# Type                 8627181
# Severity             8627181
# StartTime(UTC)       8627181
# EndTime(UTC)         8627181
# Precipitation(in)    8627181
# TimeZone             8627181
# AirportCode          8627181
# LocationLat          8627181
# LocationLng          8627181
# City                 8610269
# County               8627181
# State                8627181
# ZipCode              8557982
# dtype: int64

# %%
denver_weather = us_weather_df[us_weather_df['County'] == 'Denver']
denver_weather.head()
# Out:
#            EventId  Type  Severity       StartTime(UTC)         EndTime(UTC)  \
# 3306893  W-3487867  Snow     Light  2016-01-07 15:02:00  2016-01-07 21:53:00
# 3306894  W-3487868   Fog  Moderate  2016-01-07 21:58:00  2016-01-07 22:33:00
# 3306895  W-3487869  Snow     Light  2016-01-07 23:19:00  2016-01-08 10:53:00
# 3306896  W-3487870  Snow  Moderate  2016-01-08 10:53:00  2016-01-08 11:11:00
# 3306897  W-3487871  Snow     Light  2016-01-08 11:11:00  2016-01-08 11:50:00
#
#          Precipitation(in)     TimeZone AirportCode  LocationLat  LocationLng  \
# 3306893               0.12  US/Mountain        KDEN      39.8466    -104.6562
# 3306894               0.00  US/Mountain        KDEN      39.8466    -104.6562
# 3306895               0.27  US/Mountain        KDEN      39.8466    -104.6562
# 3306896               0.03  US/Mountain        KDEN      39.8466    -104.6562
# 3306897               0.02  US/Mountain        KDEN      39.8466    -104.6562
#
# ...

# %%
denver_weather[['EventId','Type','Severity','StartTime(UTC)','Precipitation(in)','LocationLat','LocationLng','City','County','State']]
# Out:
#            EventId  Type  Severity       StartTime(UTC)  LocationLat  \
# 3306893  W-3487867  Snow     Light  2016-01-07 15:02:00      39.8466
# 3306894  W-3487868   Fog  Moderate  2016-01-07 21:58:00      39.8466
# 3306895  W-3487869  Snow     Light  2016-01-07 23:19:00      39.8466
# 3306896  W-3487870  Snow  Moderate  2016-01-08 10:53:00      39.8466
# 3306897  W-3487871  Snow     Light  2016-01-08 11:11:00      39.8466
# ...            ...   ...       ...                  ...          ...
# 3309690  W-3490664  Snow     Heavy  2022-12-29 05:50:00      39.8466
# 3309691  W-3490665  Snow  Moderate  2022-12-29 06:53:00      39.8466
# 3309692  W-3490666  Snow     Light  2022-12-29 07:53:00      39.8466
# 3309693  W-3490667  Snow  Moderate  2022-12-29 08:53:00      39.8466
# 3309694  W-3490668  Snow     Light  2022-12-29 09:34:00      39.8466
#
#          LocationLng    City  County State
# 3306893    -104.6562  Denver  Denver    CO
# 3306894    -104.6562  Denver  Denver    CO
# ...

# %%
denver_weather.dtypes
# Out:
# EventId               object
# Type                  object
# Severity              object
# StartTime(UTC)        object
# EndTime(UTC)          object
# Precipitation(in)    float64
# TimeZone              object
# AirportCode           object
# LocationLat          float64
# LocationLng          float64
# City                  object
# County                object
# State                 object
# ZipCode              float64
# dtype: object

# %%
denver_weather.count()
# Out:
# EventId              2802
# Type                 2802
# Severity             2802
# StartTime(UTC)       2802
# EndTime(UTC)         2802
# Precipitation(in)    2802
# TimeZone             2802
# AirportCode          2802
# LocationLat          2802
# LocationLng          2802
# City                 2802
# County               2802
# State                2802
# ZipCode              2802
# dtype: int64

# %%
miami_weather = us_weather_df[us_weather_df['County'] == 'Miami']
miami_weather.head()
# Out:
#            EventId  Type Severity       StartTime(UTC)         EndTime(UTC)  \
# 1938755  W-2045682  Rain    Light  2016-01-01 15:00:00  2016-01-01 15:30:00
# 1938756  W-2045683  Snow    Light  2016-01-01 17:28:00  2016-01-01 18:15:00
# 1938757  W-2045684  Snow    Light  2016-01-03 22:27:00  2016-01-03 22:58:00
# 1938758  W-2045685  Snow    Light  2016-01-04 01:19:00  2016-01-04 01:46:00
# 1938759  W-2045686  Snow    Light  2016-01-04 01:58:00  2016-01-04 02:05:00
#
#          Precipitation(in)    TimeZone AirportCode  LocationLat  LocationLng  \
# 1938755                0.0  US/Eastern        KGUS      40.6481     -86.1521
# 1938756                0.0  US/Eastern        KGUS      40.6481     -86.1521
# 1938757                0.0  US/Eastern        KGUS      40.6481     -86.1521
# 1938758                0.0  US/Eastern        KGUS      40.6481     -86.1521
# 1938759                0.0  US/Eastern        KGUS      40.6481     -86.1521
#
#                City County State  ZipCode
# ...

# %%
miami_weather[['EventId','Type','Severity','StartTime(UTC)','LocationLat','LocationLng','City','County','State']]
# Out:
#            EventId  Type Severity       StartTime(UTC)  LocationLat  \
# 1938755  W-2045682  Rain    Light  2016-01-01 15:00:00      40.6481
# 1938756  W-2045683  Snow    Light  2016-01-01 17:28:00      40.6481
# 1938757  W-2045684  Snow    Light  2016-01-03 22:27:00      40.6481
# 1938758  W-2045685  Snow    Light  2016-01-04 01:19:00      40.6481
# 1938759  W-2045686  Snow    Light  2016-01-04 01:58:00      40.6481
# ...            ...   ...      ...                  ...          ...
# 1946636  W-2053563  Rain    Light  2022-12-31 10:03:00      40.6481
# 1946637  W-2053564  Rain    Light  2022-12-31 10:05:00      40.6481
# 1946638  W-2053565   Fog   Severe  2022-12-31 11:52:00      40.6481
# 1946639  W-2053566   Fog   Severe  2022-12-31 12:15:00      40.6481
# 1946640  W-2053567   Fog   Severe  2022-12-31 12:30:00      40.6481
#
#          LocationLng        City County State
# 1938755     -86.1521  Deer Creek  Miami    IN
# 1938756     -86.1521  Deer Creek  Miami    IN
# ...

# %%
miami_weather.count()
# Out:
# EventId              7886
# Type                 7886
# Severity             7886
# StartTime(UTC)       7886
# EndTime(UTC)         7886
# Precipitation(in)    7886
# TimeZone             7886
# AirportCode          7886
# LocationLat          7886
# LocationLng          7886
# City                 7886
# County               7886
# State                7886
# ZipCode              7886
# dtype: int64
