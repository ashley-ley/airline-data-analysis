# %%
import pandas as pd
from pathlib import Path

# %%
us_weather_path = Path("Weather_Data/united_states_weather.csv")

# %%
us_weather_df = pd.read_csv(us_weather_path, encoding="ISO-8859-1")

# %%
us_weather_df.head()
# Out:
#   EventId  Type Severity       StartTime(UTC)         EndTime(UTC)  \
# 0     W-1  Snow    Light  2016-01-06 23:14:00  2016-01-07 00:34:00
# 1     W-2  Snow    Light  2016-01-07 04:14:00  2016-01-07 04:54:00
# 2     W-3  Snow    Light  2016-01-07 05:54:00  2016-01-07 15:34:00
# 3     W-4  Snow    Light  2016-01-08 05:34:00  2016-01-08 05:54:00
# 4     W-5  Snow    Light  2016-01-08 13:54:00  2016-01-08 15:54:00
#
#    Precipitation(in)     TimeZone AirportCode  LocationLat  LocationLng  \
# 0               0.00  US/Mountain        K04V      38.0972    -106.1689
# 1               0.00  US/Mountain        K04V      38.0972    -106.1689
# 2               0.03  US/Mountain        K04V      38.0972    -106.1689
# 3               0.00  US/Mountain        K04V      38.0972    -106.1689
# 4               0.00  US/Mountain        K04V      38.0972    -106.1689
#
#        City    County State  ZipCode
# 0  Saguache  Saguache    CO  81149.0
# 1  Saguache  Saguache    CO  81149.0
# ...

# %%
us_weather_df[us_weather_df['City'] == 'Dallas'].count()
# Out:
# EventId              15071
# Type                 15071
# Severity             15071
# StartTime(UTC)       15071
# EndTime(UTC)         15071
# Precipitation(in)    15071
# TimeZone             15071
# AirportCode          15071
# LocationLat          15071
# LocationLng          15071
# City                 15071
# County               15071
# State                15071
# ZipCode              15071
# dtype: int64

# %%
dallas_weather = us_weather_df[us_weather_df['City'] == 'Dallas']
dallas_weather.head()
# Out:
#            EventId  Type  Severity       StartTime(UTC)         EndTime(UTC)  \
# 1352454  W-1426760  Rain     Light  2016-01-06 15:53:00  2016-01-06 16:53:00
# 1352455  W-1426761  Rain     Light  2016-01-07 01:39:00  2016-01-07 02:00:00
# 1352456  W-1426762  Rain     Light  2016-01-07 02:18:00  2016-01-07 02:41:00
# 1352457  W-1426763  Rain     Heavy  2016-01-07 02:41:00  2016-01-07 03:06:00
# 1352458  W-1426764  Rain  Moderate  2016-01-07 03:06:00  2016-01-07 04:26:00
#
#          Precipitation(in)    TimeZone AirportCode  LocationLat  LocationLng  \
# 1352454               0.00  US/Central        KRBD      32.6809     -96.8682
# 1352455               0.21  US/Central        KRBD      32.6809     -96.8682
# 1352456               0.08  US/Central        KRBD      32.6809     -96.8682
# 1352457               0.83  US/Central        KRBD      32.6809     -96.8682
# 1352458               0.32  US/Central        KRBD      32.6809     -96.8682
#
#            City  County State  ZipCode
# ...

# %%
us_weather_df = dallas_weather[['EventId','Type','Severity','StartTime(UTC)','AirportCode','LocationLat','LocationLng','City','County','State']]
us_weather_df
# Out:
#            EventId  Type  Severity       StartTime(UTC) AirportCode  \
# 1352454  W-1426760  Rain     Light  2016-01-06 15:53:00        KRBD
# 1352455  W-1426761  Rain     Light  2016-01-07 01:39:00        KRBD
# 1352456  W-1426762  Rain     Light  2016-01-07 02:18:00        KRBD
# 1352457  W-1426763  Rain     Heavy  2016-01-07 02:41:00        KRBD
# 1352458  W-1426764  Rain  Moderate  2016-01-07 03:06:00        KRBD
# ...            ...   ...       ...                  ...         ...
# 6503719  W-6855423  Rain     Light  2022-12-31 11:55:00        KPUJ
# 6503720  W-6855424  Rain     Light  2022-12-31 12:35:00        KPUJ
# 6503721  W-6855425   Fog    Severe  2022-12-31 13:55:00        KPUJ
# 6503722  W-6855426  Rain     Light  2022-12-31 16:35:00        KPUJ
# 6503723  W-6855427  Rain     Light  2022-12-31 18:15:00        KPUJ
#
#          LocationLat  LocationLng    City    County State
# 1352454      32.6809     -96.8682  Dallas    Dallas    TX
# ...

# %%
# Assuming 'StartTime(UTC)' column is in datetime format
us_weather_df['StartTime(UTC)'] = pd.to_datetime(us_weather_df['StartTime(UTC)'])
# Out:
# C:\Users\14029\AppData\Local\Temp\ipykernel_135844\372007573.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_weather_df['StartTime(UTC)'] = pd.to_datetime(us_weather_df['StartTime(UTC)'])

# %%
dallas_weather_df_2022 = us_weather_df[us_weather_df['StartTime(UTC)'].dt.year == 2022]
dallas_weather_df_2022.head()
# Out:
#            EventId  Type Severity      StartTime(UTC) AirportCode  \
# 1355586  W-1429892  Rain    Light 2022-01-01 07:01:00        KRBD
# 1355587  W-1429893  Rain    Light 2022-01-01 07:53:00        KRBD
# 1355588  W-1429894  Rain    Light 2022-01-01 11:53:00        KRBD
# 1355589  W-1429895  Rain    Light 2022-01-08 13:53:00        KRBD
# 1355590  W-1429896   Fog   Severe 2022-01-08 14:53:00        KRBD
#
#          LocationLat  LocationLng    City  County State
# 1355586      32.6809     -96.8682  Dallas  Dallas    TX
# 1355587      32.6809     -96.8682  Dallas  Dallas    TX
# 1355588      32.6809     -96.8682  Dallas  Dallas    TX
# 1355589      32.6809     -96.8682  Dallas  Dallas    TX
# 1355590      32.6809     -96.8682  Dallas  Dallas    TX

# %%
dallas_weather_df_2022.to_csv('Weather_Data/dallas_weather_2022.csv')
